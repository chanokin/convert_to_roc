# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import glob
# from focal import Focal, focal_to_spike, spike_trains_to_images_g
from scipy.signal import convolve2d
from scipy import misc
import cv2

from compete import Competitor, Competition

# %%
image_files = sorted( glob.glob('../test_images/*.png') )
img = cv2.cvtColor( cv2.imread(image_files[5]), cv2.COLOR_BGR2RGB ).astype('float')
# img = misc.face()
img /= 255.0
plt.figure()
plt.imshow(img)
plt.show()

# %%
c = Competition()

plt.figure(figsize=(10, 6))
ax = plt.subplot(2, 3, 1)
ax.set_title('original')
plt.imshow(img, vmin=0., vmax=1.)
for i, k in enumerate(c._source_ops):
    ax = plt.subplot(2, 3, i + 2)
    ax.set_title(k)
    plt.imshow(c._source_ops[k](img), cmap='gray', vmin=0., vmax=1.)
plt.show()
# Out:
# center-surround
# {'input': 'luma', 'center_std_dev': 0.8, 'surround_mult': 6.7, 'kernel_width': 5, 'off_center': True, 'sampling': 1}
# center-surround
# {'input': 'luma', 'center_std_dev': 1.04, 'surround_mult': 6.7, 'kernel_width': 11, 'off_center': False, 'sampling': 1}
# center-surround
# {'input': 'luma', 'center_std_dev': 8, 'surround_mult': 4.8, 'kernel_width': 61, 'off_center': True, 'sampling': 5}
# center-surround
# {'input': 'luma', 'center_std_dev': 10.4, 'surround_mult': 4.8, 'kernel_width': 243, 'off_center': False, 'sampling': 5}
# gaussian
# {'input': 'blue', 'std_dev': 1.1, 'kernel_width': 11, 'sampling': 3}
# gaussian
# {'input': 'blue', 'std_dev': 2.1, 'kernel_width': 21, 'sampling': 7}
# gaussian
# {'input': 'yellow', 'std_dev': 1.1, 'kernel_width': 11, 'sampling': 3}
# gaussian
# {'input': 'yellow', 'std_dev': 2.1, 'kernel_width': 21, 'sampling': 7}
# gaussian
# {'input': 'red', 'std_dev': 1.1, 'kernel_width': 11, 'sampling': 3}
# gaussian
# ...
